# %% [markdown]
# <a href="https://colab.research.google.com/github/manik910/Python-practice/blob/main/app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install phonenumbers

import phonenumbers
from phonenumbers import geocoder, carrier

# Enter the phone number with country code (e.g., +1 for USA, +91 for India)
number = "+919182738998"
parsed_number = phonenumbers.parse(number)

# Get Country Name
location = geocoder.description_for_number(parsed_number, "en")
print(f"Location: {location}")

# Get Service Provider (Carrier)
service_provider = carrier.name_for_number(parsed_number, "en")
print(f"Service Provider: {service_provider}")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 26.2 MB/s eta 0:00:00
# ...
# Location: India
# Service Provider: Reliance Jio

# %%
import phonenumbers
from phonenumbers import geocoder, carrier

# Enter the phone number with country code (e.g., +1 for USA, +91 for India)
number = "+919182738998"
parsed_number = phonenumbers.parse(number)

# Get Country Name
location = geocoder.description_for_number(parsed_number, "en")
print(f"Location: {location}")

# Get Service Provider (Carrier)
service_provider = carrier.name_for_number(parsed_number, "en")
print(f"Service Provider: {service_provider}")
# Out:
# Location: India
# Service Provider: Reliance Jio

# %%
import phonenumbers
from phonenumbers import geocoder, carrier

# Enter the phone number with country code (e.g., +1 for USA, +91 for India)
number = "+919182738998"
parsed_number = phonenumbers.parse(number)
number = "+919182738998"
parsed_number = phonenumbers.parse(number)

# Get Country Name
location = geocoder.description_for_number(parsed_number, "en")
print(f"Location: {location}")

# Get Service Provider (Carrier)
service_provider = carrier.name_for_number(parsed_number, "en")
print(f"Service Provider: {service_provider}")

# Get Country Name
location = geocoder.description_for_number(parsed_number, "en")
print(f"Location: {location}")

# Get Service Provider (Carrier)
Live_location = carrier.name_for_number(parsed_number, "en")
print(f"Live_location: {Live_location}")
# Out:
# Location: India
# Live_location: Reliance Jio
