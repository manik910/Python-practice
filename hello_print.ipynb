# %% [markdown]
# <a href="https://colab.research.google.com/github/manik910/Python-practice/blob/main/hello_print.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('manik')
# Out:
# manik

# %%
print('hello')
# Out:
# hello
