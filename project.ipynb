# %% [markdown]
# <a href="https://colab.research.google.com/github/manik910/Python-practice/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e725ba06-503c-4387-b651-9819bb95a76e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e725ba06-503c-4387-b651-9819bb95a76e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("Salary.csv")
print(df)
print(df.describe())
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
m = pd.read_csv("Salary.csv")

print(m.head())
print(m)

average_salary_by_gender = m.groupby('Gender')['Salary'].mean().reset_index()

plt.figure(figsize=(8, 6))
plt.bar(average_salary_by_gender['Gender'], average_salary_by_gender['Salary'], color=['skyblue', 'lightcoral', 'lightgreen'])
plt.title('Average Salary by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Salary')
print()
plt.show()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

m = pd.read_csv("Salary.csv")
print(m)

# Filter for Male employees
male_df = m[m['Gender'] == 'Male']


average_salary_female_by_experience = male_df.groupby('Years of Experience')['Salary'].mean().reset_index()

x = average_salary_male_by_experience['Years of Experience']
y = average_salary_male_by_experience['Salary']


plt.plot(x, y, marker='*', linestyle='-', color='purple')
plt.title('Average Salary for Males by Years of Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Average Salary')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
m = pd.read_csv("Salary.csv")

print(m.head())
print(m)

average_salary_by_gender = m.groupby('Gender')['Salary'].mean().reset_index()


plt.plot(average_salary_by_gender['Gender'], average_salary_by_gender['Salary'])
plt.title('Average Salary by Gender')
plt.plot(x, y, marker='*', linestyle='-', color='purple')
plt.xlabel('Gender')
plt.ylabel('Average Salary')
print()
plt.show()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# ...

# %%
x = 1
y = 1

  print("x==y value is:",(x==y))
  if x == y:
   print("if block statements executed")
# Out:
#   File "/tmp/ipython-input-2972440450.py", line 4
#     print("x==y value is:",(x==y))
#     ^
# IndentationError: unexpected indent

# %%
import matplotlib.pyplot as plt
months=["january","february","march","april","may","june","july","august","september","october","november","december"]
sales=[100000,210000,100000,240000,200000,120000,230000,170000,220000,260000,140000,180000]
plt.title("MONTHLY SALES")
plt.xlabel("MONTHS")
plt.ylabel("sales")
plt.plot(months,sales,marker=".")
plt.xticks(rotation=50)
plt.show()

# %%
import matplotlib.pyplot as plt
months=["january","february","march","april","may","june","july","august","september","october","november","december"]
sales=[150000,210000,100000,240000,200000,120000,230000,170000,220000,260000,140000,180000]
plt.title("MONTHLY SALES")
plt.xlabel("MONTHS")
plt.ylabel("sales")
plt.bar(months,sales)
plt.xticks(rotation=45)
plt.show()
