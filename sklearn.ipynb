# %% [markdown]
# <a href="https://colab.research.google.com/github/manik910/Python-practice/blob/main/sklearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

d = {
 "Company": ["Google", "Twitter", "Google", "LinkedIn"],
 "Role": ["Data Scientist", "Sales manager", "HR", "HR"]
}

df = pd.DataFrame(d)    #obj=class labelencoder()
label_encoder = LabelEncoder() #it  is method

df["Company_n"] = label_encoder.fit_transform(df['Company']) # fit_transform is usedto transform old company name to new name and alp to number
df["Role_n"] = label_encoder.fit_transform(df['Role'])

print()
print(df)
# Out:
#     Company            Role  Company_n  Role_n
# 0    Google  Data Scientist          0       0
# 1   Twitter   Sales manager          2       2
# 2    Google              HR          0       1
# 3  LinkedIn              HR          1       1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'area': [1, 2, 3, 4],
    'rice_packs': [10, 20, 30, 40]
}

df = pd.DataFrame(data)

print("DataFrame created from your data:")
display(df)
# Out:
# DataFrame created from your data:
#    area  rice_packs
# 0     1          10
# 1     2          20
# 2     3          30
# 3     4          40

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
d = {
      "Company": ["Google", "instgram", "gst", "LinkedIn"],
      "Role": ["Data Scientist", "Sales manager", "co", "HR"]
   }
df = pd.DataFrame(d)
label_encoder = LabelEncoder()
df['comp'] = label_encoder.fit_transform(df['Company'])
df['virat_k'] = label_encoder.fit_transform(df['Role'])
print(df)
# Out:
#     Company            Role  comp  virat_k
# 0    Google  Data Scientist     0        0
# 1  instgram   Sales manager     3        2
# 2       gst              co     2        3
# 3  LinkedIn              HR     1        1

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

d = {
        "x" : [10, 20, 50, 40, 50],
        "y" : [75, 50, 75, 100, 125]
}

df = pd.DataFrame(d)
mm_scale = MinMaxScaler(feature_range = (0, 1))

print(df)

one_col = mm_scale.fit_transform(df[["x"]])
one_col2 = mm_scale.fit_transform(df[['y']])

print(one_col)
print(one_col2)
# Out:
#     x    y
# 0  10   75
# 1  20   50
# 2  50   75
# 3  40  100
# 4  50  125
# [[0.  ]
#  [0.25]
#  [1.  ]
#  [0.75]
#  [1.  ]]
# [[0.33333333]
#  [0.        ]
#  [0.33333333]
#  [0.66666667]
#  [1.        ]]

# %%
import numpy as np
from sklearn.preprocessing import FunctionTransformer

a = [[20, 40], [30, 40], [70, 60]]

f = np.array(a)

def add_ten(x):       #adding 10 to a
 return x + 10

obj = FunctionTransformer(add_ten)

result = obj.transform(f)

print(f)
print()
print(result)
# Out:
# [[20 40]
#  [30 40]
#  [70 60]]
#
# [[30 50]
#  [40 50]
#  [80 70]]

# %%
import numpy as np
from sklearn.impute import SimpleImputer
import pandas as pd

students = [
                   [85, 'M', 'verygood'],
                   [95, 'F', 'excellent'],
                   [60, None, 'good'],
                   [np.nan, 'M', 'average'],
                   [70, 'M', 'good'],
                   [np.nan, None, 'verygood'],
                   [60, 'F', 'verygood'],
                   [98, 'M', 'excellent']
]

cols = ['marks', 'gender', 'result']
df = pd.DataFrame(students, columns = cols)

print(df)

imputer = SimpleImputer(missing_values = np.nan, strategy =
'mean')

result = df['marks'].values.reshape(-1, 1)

df.marks = imputer.fit_transform(result)

print(df)
# Out:
#    marks gender     result
# 0   85.0      M   verygood
# 1   95.0      F  excellent
# 2   60.0   None       good
# 3    NaN      M    average
# 4   70.0      M       good
# 5    NaN   None   verygood
# 6   60.0      F   verygood
# 7   98.0      M  excellent
#    marks gender     result
# 0   85.0      M   verygood
# 1   95.0      F  excellent
# 2   60.0   None       good
# 3   78.0      M    average
# 4   70.0      M       good
# 5   78.0   None   verygood
# 6   60.0      F   verygood
# 7   98.0      M  excellent

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6a7adf69-dd8f-4ddb-b033-6179ea0c12b2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6a7adf69-dd8f-4ddb-b033-6179ea0c12b2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from PIL import Image                         #pil meaning python image lib
from matplotlib import pyplot as plt
image = Image.open('jpg.jpg')
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
 from PIL import Image
 import matplotlib.pyplot as plt
 image = Image.open("virat.jpg")
 image.thumbnail((5000,5000))
 plt.imshow(image)
 plt.axis('off')
 plt.show()

# %%
from PIL import Image
import matplotlib.pyplot as plt
image = Image.open("virat.jpg")
hoz_flip = image.transpose(Image.FLIP_LEFT_RIGHT)
plt.subplot(312)
plt.imshow(hoz_flip)
plt.axis('off')
plt.show()

# %%
import pandas as pd
df=pd.read_csv('Salary.csv')
print(df)
total=df[['Age']].sum()
print(total)
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
import pandas as pd
df=pd.read_csv('Salary.csv')
total=df['Gender'].value_counts()  #total counts of gender
print(total)
# Out:
# Gender
# Male      3674
# Female    3014
# Other       14
# Name: count, dtype: int64

# %%
import pandas as pd
df=pd.read_csv('Salary.csv')
total=df['Gender'].info()  #total infos of gender
print(total)
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6704 entries, 0 to 6703
# Series name: Gender
# Non-Null Count  Dtype
# --------------  -----
# 6702 non-null   object
# dtypes: object(1)
# memory usage: 52.5+ KB
# None

# %%
import matplotlib.pyplot as plt
area = [1,2,3,4]
rice_packs = [10,20,30,40]
plt.scatter(area,rice_packs)
plt.show()
