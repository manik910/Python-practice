# %% [markdown]
# <a href="https://colab.research.google.com/github/manik910/Python-practice/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = [(1, 3), (4, 1), (2, 2)]

# Sort using lambda to target index 1 (the second element)
sorted_data = sorted(data, key=lambda x: x[1])

print("Sorted List:", sorted_data)
# Out:
# Sorted List: [(4, 1), (2, 2), (1, 3)]

# %%
import matplotlib.pyplot as plt
data=[1,20,3,60,5,70]
plt.boxplot(data)
plt.show()

# %%
import matplotlib.pyplot as plt
data=[30,34,45,50,60,65,70,75]
data1=[30,34,45,50,60,65,70,75]
plt.boxplot(data)
plt.boxplot(data1)
plt.show()

# %%
import matplotlib.pyplot as plt

data = [12, 15, 13, 20, 19, 20, 11, 19, 11, 12, 19, 13, 15, 16, 18, 13]
data1 = [12, 15, 13, 20, 19, 20, 11, 19, 11, 12, 19, 13, 15, 16, 18, 13]

plt.xlabel("X")
plt.ylabel("Y")
plt.title("Histogram Plot")

plt.hist(data, bins = 20)
plt.hist(data1,bins = 20)
plt.show()

# %%
import matplotlib.pyplot as plt

data = [12, 15, 13, 20, 19, 20, 11, 19, 45, 12, 19, 13, 15, 16, 18, 13]
data1 =[12, 15, 13, 20, 19, 20, 11, 19, 45, 12, 19, 13, 15, 16, 18, 13]

plt.xlabel("X")
plt.ylabel("Y")
plt.title("Histogram Plot")

plt.hist(data, bins = 20)
plt.hist(data1,bins = 20)
plt.show()
